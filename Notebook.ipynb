# %%
import pathlib
import PIL

from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
data_dir = pathlib.Path('dataset')
image_count = len(list(data_dir.glob('**/*.jpg')))
print(f'Total of images is {image_count}')
# Out:
# Total of images is 23020

# %% [markdown]
# ###  Building

# %%
building = list(data_dir.glob('train/building/*'))
PIL.Image.open(str(building[50]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x20716591C48>

# %% [markdown]
# ### Forest

# %%
forest = list(data_dir.glob('train/forest/*'))
PIL.Image.open(str(forest[20]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x20715A99A08>

# %% [markdown]
# ### Glacier

# %%
glacier = list(data_dir.glob('train/glacier/*'))
PIL.Image.open(str(glacier[90]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x20715B8CA88>

# %% [markdown]
# ### Mountain

# %%
mountain = list(data_dir.glob('train/mountain/*'))
PIL.Image.open(str(mountain[90]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x20715C31B88>

# %% [markdown]
# ### Sea

# %%
sea = list(data_dir.glob('train/sea/*'))
PIL.Image.open(str(sea[80]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x20715CD8DC8>

# %% [markdown]
# ### Street

# %%
street = list(data_dir.glob('train/street/*'))
PIL.Image.open(str(street[40]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x20715D80188>
