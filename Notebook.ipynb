# %%
import pathlib
import PIL

from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
data_dir = pathlib.Path('dataset')
image_count = len(list(data_dir.glob('**/*.jpg')))
print(f'Total of images is {image_count}')
# Out:
# Total of images is 23020

# %% [markdown]
# ###  Buildings

# %%
buildings = list(data_dir.glob('train/buildings/*'))
PIL.Image.open(str(buildings[50]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x12BCD4C1788>

# %% [markdown]
# ### Forest

# %%
forest = list(data_dir.glob('train/forest/*'))
PIL.Image.open(str(forest[20]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x12BCC87B108>

# %% [markdown]
# ### Glacier

# %%
glacier = list(data_dir.glob('train/glacier/*'))
PIL.Image.open(str(glacier[100]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x12BCC9630C8>
